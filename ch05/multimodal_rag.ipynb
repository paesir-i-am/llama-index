# %% [markdown]
# ### 5.2 데이터 준비하기

# %%
# !pip install llama-index==0.12.35
# !pip install --upgrade "llama-index-core>=0.13.0" --trusted-host pypi.org --trusted-host files.pythonhosted.org
# !pip install wikipedia
# Out:
# Requirement already satisfied: llama-index==0.12.35 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (0.12.35)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.4.8)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.4.1)
# Collecting llama-index-core<0.13,>=0.12.35 (from llama-index==0.12.35)
#   Using cached llama_index_core-0.12.52.post1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.8.0)
# Requirement already satisfied: llama-index-llms-openai<0.4,>=0.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.3.44)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5,>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.4.11)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index==0.12.35) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index==0.12.35) (1.107.2)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (3.12.15)
# Requirement already satisfied: aiosqlite in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2.2.0)
# Requirement already satisfied: dataclasses-json in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2025.9.0)
# Requirement already satisfied: httpx in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.28.1)
# Collecting llama-index-workflows<2,>=1.0.1 (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35)
#   Using cached llama_index_workflows-1.3.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (3.5)
# Requirement already satisfied: numpy in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (11.3.0)
# Requirement already satisfied: platformdirs in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (4.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2.11.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.11.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.9.0)
# Requirement already satisfied: wrapt in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.20.1)
# Requirement already satisfied: griffe in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (3.1.6)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (4.13.5)
# Requirement already satisfied: defusedxml>=0.7.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (2.2.3)
# Requirement already satisfied: pypdf<6,>=5.1.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (5.9.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (2.8)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-workflows<2,>=1.0.1->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index==0.12.35) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index==0.12.35) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index==0.12.35) (0.10.0)
# Requirement already satisfied: sniffio in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index==0.12.35) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index==0.12.35) (3.10)
# Requirement already satisfied: certifi in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.4.1)
# Requirement already satisfied: llama-cloud==0.1.35 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index==0.12.35) (0.1.35)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index==0.12.35) (0.6.21)
# Requirement already satisfied: llama-cloud-services>=0.6.21 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index==0.12.35) (0.6.54)
# Requirement already satisfied: click<9,>=8.1.7 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-cloud-services>=0.6.21->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index==0.12.35) (8.2.1)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-cloud-services>=0.6.21->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index==0.12.35) (1.1.1)
# Requirement already satisfied: joblib in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index==0.12.35) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index==0.12.35) (2025.9.1)
# Requirement already satisfied: six>=1.5 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index==0.12.35) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (24.2)
# Requirement already satisfied: colorama>=0.4 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.13,>=0.12.35->llama-index==0.12.35) (3.0.2)
# Using cached llama_index_core-0.12.52.post1-py3-none-any.whl (7.6 MB)
# Using cached llama_index_workflows-1.3.0-py3-none-any.whl (42 kB)
# Installing collected packages: llama-index-workflows, llama-index-core
#   Attempting uninstall: llama-index-workflows
#     Found existing installation: llama-index-workflows 2.2.0
#     Uninstalling llama-index-workflows-2.2.0:
#       Successfully uninstalled llama-index-workflows-2.2.0
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.14.1
#     Uninstalling llama-index-core-0.14.1:
#       Successfully uninstalled llama-index-core-0.14.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [llama-index-core][llama-index-core]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-embeddings-huggingface 0.3.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.12.52.post1 which is incompatible.
# llama-index-vector-stores-qdrant 0.8.4 requires llama-index-core<0.15,>=0.13.0, but you have llama-index-core 0.12.52.post1 which is incompatible.
# llama-index-vector-stores-chroma 0.5.3 requires llama-index-core<0.15,>=0.13.0, but you have llama-index-core 0.12.52.post1 which is incompatible.
# llama-index-embeddings-clip 0.5.1 requires llama-index-core<0.15,>=0.13.0, but you have llama-index-core 0.12.52.post1 which is incompatible.
# llama-index-vector-stores-pinecone 0.3.0 requires llama-index-core<0.12.0,>=0.11.10, but you have llama-index-core 0.12.52.post1 which is incompatible.
# Successfully installed llama-index-core-0.12.52.post1 llama-index-workflows-1.3.0
# Collecting llama-index-core>=0.13.0
#   Using cached llama_index_core-0.14.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (3.12.15)
# Requirement already satisfied: aiosqlite in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (2.2.0)
# Requirement already satisfied: dataclasses-json in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (2025.9.0)
# Requirement already satisfied: httpx in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (0.28.1)
# Collecting llama-index-workflows<3,>=2 (from llama-index-core>=0.13.0)
#   Using cached llama_index_workflows-2.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (3.9.1)
# Requirement already satisfied: numpy in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (11.3.0)
# Requirement already satisfied: platformdirs in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (4.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (2.11.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core>=0.13.0) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (0.11.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (0.9.0)
# Requirement already satisfied: wrapt in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core>=0.13.0) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core>=0.13.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core>=0.13.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core>=0.13.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core>=0.13.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core>=0.13.0) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core>=0.13.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core>=0.13.0) (1.20.1)
# Requirement already satisfied: griffe in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core>=0.13.0) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core>=0.13.0) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-workflows<3,>=2->llama-index-core>=0.13.0) (0.4.0)
# Requirement already satisfied: idna>=2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core>=0.13.0) (3.10)
# Requirement already satisfied: click in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core>=0.13.0) (8.2.1)
# Requirement already satisfied: joblib in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core>=0.13.0) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core>=0.13.0) (2025.9.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core>=0.13.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core>=0.13.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core>=0.13.0) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.13.0) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.13.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.13.0) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core>=0.13.0) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core>=0.13.0) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core>=0.13.0) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core>=0.13.0) (24.2)
# Requirement already satisfied: colorama>=0.4 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core>=0.13.0) (0.4.6)
# Requirement already satisfied: anyio in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core>=0.13.0) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core>=0.13.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core>=0.13.0) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from anyio->httpx->llama-index-core>=0.13.0) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core>=0.13.0) (3.0.2)
# Using cached llama_index_core-0.14.1-py3-none-any.whl (11.9 MB)
# Using cached llama_index_workflows-2.2.0-py3-none-any.whl (56 kB)
# Installing collected packages: llama-index-workflows, llama-index-core
#   Attempting uninstall: llama-index-workflows
#     Found existing installation: llama-index-workflows 1.3.0
#     Uninstalling llama-index-workflows-1.3.0:
#       Successfully uninstalled llama-index-workflows-1.3.0
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.12.52.post1
#     Uninstalling llama-index-core-0.12.52.post1:
#       Successfully uninstalled llama-index-core-0.12.52.post1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [llama-index-core][llama-index-core]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-embeddings-huggingface 0.3.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-multi-modal-llms-openai 0.4.3 requires llama-index-core<0.13.0,>=0.12.3, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-indices-managed-llama-cloud 0.8.0 requires llama-index-core<0.13,>=0.12.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index 0.12.35 requires llama-index-core<0.13,>=0.12.35, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-llms-openai 0.3.44 requires llama-index-core<0.13,>=0.12.37, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-readers-llama-parse 0.4.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-cli 0.4.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-readers-file 0.4.11 requires llama-index-core<0.13,>=0.12.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-embeddings-openai 0.3.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-agent-openai 0.4.8 requires llama-index-core<0.13,>=0.12.18, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-question-gen-openai 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-readers-database 0.3.0 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-program-openai 0.3.1 requires llama-index-core<0.13.0,>=0.12.0, but you have llama-index-core 0.14.1 which is incompatible.
# llama-index-vector-stores-pinecone 0.3.0 requires llama-index-core<0.12.0,>=0.11.10, but you have llama-index-core 0.14.1 which is incompatible.
# Successfully installed llama-index-core-0.14.1 llama-index-workflows-2.2.0
# Requirement already satisfied: wikipedia in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from wikipedia) (4.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from wikipedia) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.8.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from beautifulsoup4->wikipedia) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from beautifulsoup4->wikipedia) (4.15.0)

# %% [markdown]
# # 커널 restart 후 아래 코드 실행

# %%
import wikipedia

# 위키피디아 언어 설정 (영어 위키피디아)
wikipedia.set_lang("en")

# 테스트할 문서 제목
test_title = "The Starry Night"
try:
    # 문서 내용 가져오기
    page = wikipedia.page(test_title)
    print("Wikipedia page found!")
    print("Title:", page.title)
    print("Summary:", page.summary[:500]) # 500자까지만 출력
except Exception as e:
    print(f"Error fetching Wikipedia page: {e}")
# Out:
# Wikipedia page found!
# Title: The Starry Night
# Summary: The Starry Night, often called simply Starry Night, is an oil-on-canvas painting by the Dutch Post-Impressionist painter Vincent van Gogh. Painted in June 1889, it depicts the view from the east-facing window of his asylum room at Saint-Rémy-de-Provence, just before sunrise, with the addition of an imaginary village. It has been in the permanent collection of the Museum of Modern Art in New York City since 1941, acquired through the Lillie P. Bliss Bequest. Described as a "touchstone of modern a

# %%
import wikipedia
import os
import re

# 위키피디아에서 가져올 문서 목록
wiki_titles = [
    "Water Lilies (Monet series)",
    "The Starry Night",
    "Where Do We Come From? What Are We? Where Are We Going?",
    "The Card Players",
    "Bedroom in Arles",
    "Café Terrace at Night",
    "Women in the Garden",
    "Impression, Sunrise",
    "The Kiss (Klimt)",
]

# 다운로드한 파일을 저장할 폴더 생성
output_folder = "wiki_downloads"
os.makedirs(output_folder, exist_ok=True)

def download_wikipedia_page(title):
    """위키피디아 문서를 다운로드하여 텍스트 파일로 저장"""
    try:
        page = wikipedia.page(title)
        title = title.replace(" ", "_")
        file_path = os.path.join(output_folder, f"{title}.txt")
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(page.content)
        print(f"Saved Wikipedia article: {file_path}")
        return file_path
    except Exception as e:
        print(f"Error downloading page '{title}': {str(e)}")
        return None

# %%
import requests
from urllib.parse import quote

def get_wikidata_id(title):
    """위키피디아 문서에서 위키데이터 ID 조회"""

    # 문서 제목을 URL에 사용할 수 있도록 인코딩 (공백 등 특수문자 처리)
    encoded_title = quote(title)
    wiki_api_url = f"https://en.wikipedia.org/w/api.php?action=query&titles={encoded_title}&prop=pageprops&format=json"

    # 요청을 보낼 때 User-Agent 없이 요청하면 차단됨
    headers = {"User-Agent": "Mozilla/5.0"}
    # 위키피디아 API에 GET 요청을 보내고 응답을 받아옴
    response = requests.get(wiki_api_url, headers=headers)
    
    # 응답 상태가 200이면 정상이지만, 아니면 오류 처리
    if response.status_code != 200:
        print(f"Failed to fetch Wikidata ID for {title}. HTTP Status:{response.status_code}")
        return None

    data = response.json()

    # JSON 데이터에서 'query' → 'pages' 키를 찾아 문서 정보 가져오기
    pages = data.get("query", {}).get("pages", {})
    
    # 페이지 정보에서 'pageprops' 내 'wikibase_item' 속성을 찾아 위키데이터 ID(QID) 추출
    for page_id, page_data in pages.items():
        if "pageprops" in page_data and "wikibase_item" in page_data["pageprops"]:
            return page_data["pageprops"]["wikibase_item"]
    return None

# %%
import hashlib

def get_md5_path(filename):
    # 파일명에서 공백을 제거하고 첫 글자를 소문자로 변환
    filename_normalized = filename.replace(' ', '_')
    
    # MD5 해시 생성
    md5 = hashlib.md5(filename_normalized.encode('utf-8')).hexdigest()
    return f"{md5[0]}/{md5[0:2]}/{filename_normalized}"

# %%
import requests

def get_infobox_image(wikidata_id):
    """위키데이터에서 대표 이미지 URL 가져오기"""
    if not wikidata_id:
        return None
    
    wikidata_url = f"https://www.wikidata.org/wiki/Special:EntityData/{wikidata_id}.json"
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(wikidata_url, headers=headers)

    # 응답 상태가 200이면 정상이지만, 아니면 오류 처리
    if response.status_code != 200:
        print(f"Failed to fetch Wikidata data for {wikidata_id}. HTTP Status: {response.status_code}")
        return None
    
    # 응답 데이터를 JSON 형식으로 변환
    data = response.json()
    # 'entities' 딕셔너리에서 특정 Wikidata ID(Q5582)에 해당하는 데이터 가져오기
    entity = data.get("entities", {}).get(wikidata_id, {})
    # 'claims' 항목에서 속성 정보 가져오기 (각종 메타데이터 포함)
    claims = entity.get("claims", {})
    
    # 'P18' 속성이 존재하는지 확인 (P18은 대표 이미지 속성을 의미)
    if "P18" in claims:
        image_filename = claims["P18"][0]["mainsnak"]["datavalue"]["value"]
        # 이미지 파일명을 위키미디어 URL 형식으로 변환 (MD5 해싱 적용)
        md5_path = get_md5_path(image_filename)
        # 최종적으로 위키미디어 공용(Wikimedia Commons)에서 접근 가능한 이미지 URL 반환
        return f"https://upload.wikimedia.org/wikipedia/commons/{md5_path}"
    return None

# %%
import requests	
from PIL import Image
from io import BytesIO

def download_image(url, title, max_size=800):
    if not url:
        print(f"No image found for {title}.")
        return None
    
    try:
        # PIL 라이브러리 임포트
        Image.MAX_IMAGE_PIXELS = None  # DecompressionBomb 에러 방지
        
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        # 이미지 열기
        img = Image.open(BytesIO(response.content))
        
        # 원본 크기 확인
        width, height = img.size
        print(f"Original size: {width}x{height}")
        
        # 리사이징 필요 여부 확인
        if width > max_size or height > max_size:
            # 비율 유지하면서 리사이징
            if width > height:
                new_width = max_size
                new_height = int(height * (max_size / width))
            else:
                new_height = max_size
                new_width = int(width * (max_size / height))
            
            try:
                # 고품질 리사이징 (LANCZOS)
                img.thumbnail((new_width, new_height), Image.Resampling.LANCZOS)
                print(f"Resized to: {new_width}x{new_height}")
            except Exception as e:
                print(f"Error during resize, trying with NEAREST resampling: {str(e)}")
                img.thumbnail((new_width, new_height), Image.Resampling.NEAREST)
        
        # 이미지 저장
        safe_title = sanitize_filename(title)
        image_path = os.path.join(output_folder, f"{safe_title}.jpg")
        
        # JPEG로 저장 (품질 85%)
        img.convert('RGB').save(image_path, 'JPEG', quality=85)
        print(f"Downloaded and saved image: {image_path}")
        return image_path
        
    except requests.exceptions.RequestException as e:
        print(f"Failed to download image for {title}. Error: {str(e)}")
        # 썸네일 URL이 실패하면 원본 URL로 재시도
        if "thumb" in url:
            original_url = url.split("/thumb/")[0] + "/" + url.split("/thumb/")[1].split("/")[0]
            print(f"Trying original URL: {original_url}")
            return download_image(original_url, title, max_size)
        return None
    except Exception as e:
        print(f"Error processing image for {title}. Error: {str(e)}")
        return None

# %%
def sanitize_filename(title):
    """파일명에서 특수문자를 제거하고 안전한 형식으로 변환"""
    return re.sub(r'[^a-zA-Z0-9_-]', '_', title)

# %%
for title in wiki_titles:
    text_path = download_wikipedia_page(title)
    
    if text_path:
        wikidata_id = get_wikidata_id(title)
        image_url = get_infobox_image(wikidata_id)
        download_image(image_url, title)
# Out:
# Saved Wikipedia article: wiki_downloads/Water_Lilies_(Monet_series).txt
# Original size: 5472x3648
# Resized to: 800x533
# Downloaded and saved image: wiki_downloads/Water_Lilies__Monet_series_.jpg
# Saved Wikipedia article: wiki_downloads/The_Starry_Night.txt
# Original size: 30000x23756
# Resized to: 800x633
# Downloaded and saved image: wiki_downloads/The_Starry_Night.jpg
# Saved Wikipedia article: wiki_downloads/Where_Do_We_Come_From?_What_Are_We?_Where_Are_We_Going?.txt
# Original size: 3090x1175
# Resized to: 800x304
# Downloaded and saved image: wiki_downloads/Where_Do_We_Come_From__What_Are_We__Where_Are_We_Going_.jpg
# Saved Wikipedia article: wiki_downloads/The_Card_Players.txt
# Original size: 1683x1385
# Resized to: 800x658
# Downloaded and saved image: wiki_downloads/The_Card_Players.jpg
# Saved Wikipedia article: wiki_downloads/Bedroom_in_Arles.txt
# Original size: 30000x23803
# Resized to: 800x634
# Downloaded and saved image: wiki_downloads/Bedroom_in_Arles.jpg
# Saved Wikipedia article: wiki_downloads/Café_Terrace_at_Night.txt
# Original size: 2864x3568
# Resized to: 642x800
# Downloaded and saved image: wiki_downloads/Caf__Terrace_at_Night.jpg
# Saved Wikipedia article: wiki_downloads/Women_in_the_Garden.txt
# Original size: 2024x2490
# Resized to: 650x800
# Downloaded and saved image: wiki_downloads/Women_in_the_Garden.jpg
# Error downloading page 'Impression, Sunrise': Page id "impression sun rise" does not match any pages. Try another id!
# Saved Wikipedia article: wiki_downloads/The_Kiss_(Klimt).txt
# Original size: 7376x7401
# Resized to: 797x800
# Downloaded and saved image: wiki_downloads/The_Kiss__Klimt_.jpg

# %% [markdown]
# ### 5.3 OpenAI API로 다중모달 벡터 인덱싱하기

# %%
# API 키 설정
api_key = "your_api_key_here"  # 여기에 실제 API 키 입력
# 또는 환경 변수에서 가져오기
# api_key = os.environ.get("OPENAI_API_KEY")

# %%
from llama_index.multi_modal_llms.openai import OpenAIMultiModal
from llama_index.core import SimpleDirectoryReader
from llama_index.core.schema import ImageDocument

# 이미지 데이터 로딩
image_documents = SimpleDirectoryReader("wiki_downloads").load_data()

documents = []
for doc in image_documents:
    if isinstance(doc, ImageDocument):
        documents.append(doc)

# OpenAI 다중 모달 모델 설정
openai_mm_llm = OpenAIMultiModal(
    model="gpt-4o-mini", api_key=api_key, max_new_tokens=1500
)

# 이미지 데이터를 텍스트로 변환
response_1 = openai_mm_llm.complete(
    prompt="이미지를 텍스트로 설명해주세요.",
    image_documents=documents[:2],
)

print(response_1)
# Out:
# 첫 번째 이미지는 빈센트 반 고흐의 "아를의 침실"이라는 작품입니다. 이 그림은 아를에 있는 그의 침실을 묘사하고 있으며, 노란색 침대와 나무 바닥, 그리고 창문과 벽에 걸린 그림들이 특징입니다. 방 안은 따뜻한 색조로 가득 차 있으며, 편안한 분위기를 자아냅니다.
#
# 두 번째 이미지는 "별이 빛나는 밤"이라는 작품으로, 밤하늘에 별들이 반짝이는 장면을 담고 있습니다. 거리에는 카페와 사람들이 앉아 있는 테이블이 보이며, 건물들은 따뜻한 색조로 그려져 있습니다. 전체적으로 몽환적이고 감정적인 분위기를 전달합니다.

# %% [markdown]
# ### 5.4 쿼드런트를 활용한 다중모달 RAG 구축하기

# %%
# !pip install qdrant-client
# !pip install llama-index-vector-stores-qdrant
# Out:
# Requirement already satisfied: qdrant-client in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (1.15.1)
# Requirement already satisfied: grpcio>=1.41.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client) (1.74.0)
# Requirement already satisfied: httpx>=0.20.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: numpy>=1.26 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client) (1.26.4)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client) (6.32.1)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client) (2.11.8)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client) (2.5.0)
# Requirement already satisfied: anyio in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.10.0)
# Requirement already satisfied: certifi in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.9)
# Requirement already satisfied: idna in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.3.1)
# Requirement already satisfied: llama-index-vector-stores-qdrant in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (0.8.4)
# Requirement already satisfied: grpcio<2,>=1.60.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-vector-stores-qdrant) (1.74.0)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-vector-stores-qdrant) (0.14.1)
# Requirement already satisfied: qdrant-client>=1.7.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-vector-stores-qdrant) (1.15.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.12.15)
# Requirement already satisfied: aiosqlite in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2.2.0)
# Requirement already satisfied: dataclasses-json in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2025.9.0)
# Requirement already satisfied: httpx in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2.2.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.9.1)
# Requirement already satisfied: numpy in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (11.3.0)
# Requirement already satisfied: platformdirs in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (4.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2.11.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.11.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.9.0)
# Requirement already satisfied: wrapt in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.20.1)
# Requirement already satisfied: griffe in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-workflows<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.4.0)
# Requirement already satisfied: idna>=2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.10)
# Requirement already satisfied: click in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (8.2.1)
# Requirement already satisfied: joblib in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2025.9.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.4.1)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client>=1.7.1->llama-index-vector-stores-qdrant) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client>=1.7.1->llama-index-vector-stores-qdrant) (6.32.1)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from qdrant-client>=1.7.1->llama-index-vector-stores-qdrant) (2.5.0)
# Requirement already satisfied: anyio in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (4.10.0)
# Requirement already satisfied: certifi in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.7.1->llama-index-vector-stores-qdrant) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.7.1->llama-index-vector-stores-qdrant) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.7.1->llama-index-vector-stores-qdrant) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.4.3)
# Requirement already satisfied: greenlet>=1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from anyio->httpx->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (24.2)
# Requirement already satisfied: colorama>=0.4 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-vector-stores-qdrant) (3.0.2)

# %%
import qdrant_client
from llama_index.vector_stores.qdrant import QdrantVectorStore

# 로컬 쿼드런트 벡터 스토어 생성
client = qdrant_client.QdrantClient(path="qdrant_mm_db")

# %%
# 텍스트 및 이미지 벡터 저장소 생성
text_store = QdrantVectorStore(
    client=client, collection_name="text_collection"
)

image_store = QdrantVectorStore(
    client=client, collection_name="image_collection"
)

# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install llama-index-embeddings-clip
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /private/var/folders/xp/3t6s71g53z795shvkq_psms00000gn/T/pip-req-build-jz39jn1y
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /private/var/folders/xp/3t6s71g53z795shvkq_psms00000gn/T/pip-req-build-jz39jn1y
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ftfy in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from clip==1.0) (24.2)
# Requirement already satisfied: regex in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from clip==1.0) (2025.9.1)
# Requirement already satisfied: tqdm in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from clip==1.0) (4.67.1)
# Requirement already satisfied: torch in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from clip==1.0) (2.8.0)
# Requirement already satisfied: torchvision in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from clip==1.0) (0.23.0)
# Requirement already satisfied: wcwidth in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torch->clip==1.0) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torch->clip==1.0) (4.15.0)
# Requirement already satisfied: setuptools in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torch->clip==1.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torch->clip==1.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torch->clip==1.0) (3.5)
# Requirement already satisfied: jinja2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torch->clip==1.0) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from jinja2->torch->clip==1.0) (3.0.2)
# Requirement already satisfied: numpy in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from torchvision->clip==1.0) (11.3.0)
# Requirement already satisfied: llama-index-embeddings-clip in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (0.5.1)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-embeddings-clip) (0.14.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.12.15)
# Requirement already satisfied: aiosqlite in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2.2.0)
# Requirement already satisfied: dataclasses-json in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2025.9.0)
# Requirement already satisfied: httpx in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2.2.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.5)
# Requirement already satisfied: nltk>3.8.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.9.1)
# Requirement already satisfied: numpy in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (11.3.0)
# Requirement already satisfied: platformdirs in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (4.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2.11.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.11.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.9.0)
# Requirement already satisfied: wrapt in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.20.1)
# Requirement already satisfied: griffe in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.1.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from llama-index-workflows<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.4.0)
# Requirement already satisfied: idna>=2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.10)
# Requirement already satisfied: click in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (8.2.1)
# Requirement already satisfied: joblib in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2025.9.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (24.2)
# Requirement already satisfied: colorama>=0.4 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.4.6)
# Requirement already satisfied: anyio in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from anyio->httpx->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-clip) (3.0.2)

# %%
from llama_index.core import SimpleDirectoryReader, StorageContext
from llama_index.core.indices import MultiModalVectorStoreIndex
import qdrant_client
from llama_index.embeddings.openai import OpenAIEmbedding

# 스토리지 컨텍스트 설정
storage_context = StorageContext.from_defaults(
    vector_store=text_store, image_store=image_store
)

# 문서 데이터 로딩
documents = SimpleDirectoryReader("wiki_downloads").load_data()

# OpenAI 임베딩 모델 설정 (OPENAI_API_KEY 사용)
openai_embed_model = OpenAIEmbedding(api_key=api_key)


# 멀티모달 벡터 인덱스 생성
index = MultiModalVectorStoreIndex.from_documents(
    documents,
    storage_context=storage_context,
    embed_model=openai_embed_model
)

# %%
# 텍스트 검색을 위한 설정
MAX_TOKENS = 100
retriever_engine = index.as_retriever(
    image_similarity_top_k=3
)

# 검색할 질문 입력
question = "Introduce representative works of Monet"
retrieval_results = retriever_engine.retrieve(question)
print(retrieval_results)
# Out:
# [NodeWithScore(node=TextNode(id_='2651d421-5075-46a8-a09b-c90bd0a70716', embedding=None, metadata={'file_path': '/Users/paesir/Desktop/git/llama-index/ch05/wiki_downloads/Water_Lilies_(Monet_series).txt', 'file_name': 'Water_Lilies_(Monet_series).txt', 'file_type': 'text/plain', 'file_size': 4457, 'creation_date': '2025-09-13', 'last_modified_date': '2025-09-13'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c862542f-49b1-4e48-8ac2-b534fee2bedf', node_type='4', metadata={'file_path': '/Users/paesir/Desktop/git/llama-index/ch05/wiki_downloads/Water_Lilies_(Monet_series).txt', 'file_name': 'Water_Lilies_(Monet_series).txt', 'file_type': 'text/plain', 'file_size': 4457, 'creation_date': '2025-09-13', 'last_modified_date': '2025-09-13'}, hash='2d2032ee12e08778a48685b8a439bb81d0d5a0a180644f6dacbda14d3d6992b6'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='d96738f1-cb58-40a6-8aa9-06122c90092b', node_type='1', metadata={}, hash='f492f47a06284791cb1fc4ac72c18fe3d79535e489d4b37eb37dff38d9823147')}, metadata_template='{key}: {value}', metadata_separator='\n', text='Water Lilies (French: Nymphéas [nɛ̃.fe.a]) is a series of approximately 250 oil paintings by French Impressionist Claude Monet (1840–1926). The paintings depict his flower garden at his home in Giverny, and were the main focus of his artistic production during the last 31 years of his life. Many of the works were painted while Monet suffered from cataracts.\n\n\n== Background ==\nMonet\'s long-standing preference for producing and exhibiting a series of paintings related by subject and perspective began in 1889, with at least ten paintings done at the Valley of the Creuse, which were shown at the Galerie Georges Petit. Among his other famous series are his Haystacks.\nDuring the 1920s, the state of France built a pair of oval rooms at the Musée de l\'Orangerie as a permanent home for eight large water lily murals by Monet. The exhibit opened to the public on 16 May 1927, a few months after Monet\'s death. Sixty water lily paintings from around the globe were assembled for a special exhibition at the Musée de l\'Orangerie in 1999.\nThe paintings are on prominent display at museums all over the world, including the Musée Marmottan Monet, the Musée d\'Orsay in Paris, the Tate, the Metropolitan Museum of Art, Museum of Modern Art in New York, the Art Institute of Chicago, the Saint Louis Art Museum, the Nelson-Atkins Museum of Art in Kansas City, Missouri, the Carnegie Museum of Art, Princeton University Art Museum, the National Museum of Wales, the Musée des Beaux-Arts de Nantes, The Toledo Museum of Art, the Cleveland Museum of Art, the Portland Art Museum, and the Legion of Honor. In 2020, the Museum of Fine Arts, Boston celebrated its 150th anniversary with some of Monet\'s Water Lilies paintings.\n\n\n== The paintings at auction ==\n\nOn 19 June 2007, one of Monet\'s Water Lily paintings sold for £18.5 million at a Sotheby\'s auction in London. On 24 June 2008 another of his Water Lily paintings, Le Bassin Aux Nymphéas, sold for almost £41 million at Christie\'s in London, almost double the estimate of £18 to £24 million.\nIn May 2010, it was announced that the 1906 Nymphéas work would be auctioned in London in June 2010. The painting had an estimated sale price of between £30 and £40 million. Giovanna Bertazzoni, Christie\'s auction house director and head of impressionist and modern art, said, "Claude Monet\'s water-lily paintings are amongst the most recognised and celebrated works of the 20th Century and were hugely influential to many of the following generations of artists." The sale took place on 23 June 2010 at the auction house and the painting attracted bids of up to £29 mi ...

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/paesir/Desktop/git/llama-index/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt
from PIL import Image

def plot_images(image_paths):
    images_shown = 0
    plt.figure(figsize=(16, 9))
    for img_path in image_paths:
        if os.path.isfile(img_path):
            image = Image.open(img_path)

            plt.subplot(2, 3, images_shown + 1)
            plt.imshow(image)
            plt.xticks([])
            plt.yticks([])

            images_shown += 1
            if images_shown >= 9:
                break

# %%
from llama_index.core.schema import ImageNode
import os

retrieved_image = []
for res_node in retrieval_results:
    if isinstance(res_node.node, ImageNode):
        retrieved_image.append(res_node.node.metadata["file_path"])

# 검색된 이미지 출력
plot_images(retrieved_image)

# %% [markdown]
# ### 5.5 이미지 기반 RAG 시스템 구축

# %%
import os

wiki_titles = [
    "Nave nave moe",
]

output_folder = "wiki_downloads2"
os.makedirs(output_folder, exist_ok=True)

for title in wiki_titles:
    text_path = download_wikipedia_page(title)

    if text_path:
        wikidata_id = get_wikidata_id(title)
        image_url = get_infobox_image(wikidata_id)
        if image_url:
            print(f"해당 URL로부터 다운로드를 진행 중입니다: {image_url}")
            download_image(image_url, title)
# Out:
# Saved Wikipedia article: wiki_downloads2/Nave_nave_moe.txt
# 해당 URL로부터 다운로드를 진행 중입니다: https://upload.wikimedia.org/wikipedia/commons/9/95/Paul_Gauguin_068.jpg
# Original size: 4356x3304
# Resized to: 800x606
# Downloaded and saved image: wiki_downloads2/Nave_nave_moe.jpg

# %%
input_image = "wiki_downloads2/Nave_nave_moe.jpg"
plot_images([input_image])

# %%
retriever_engine = index.as_retriever(image_similarity_top_k=1)
retrieval_results = retriever_engine.image_to_image_retrieve(
    "wiki_downloads2/Nave_nave_moe.jpg"
)

retrieved_images = []
for res in retrieval_results:
    retrieved_images.append(res.node.metadata["file_path"])

plot_images(retrieved_images)

# %%
from llama_index.multi_modal_llms.openai import OpenAIMultiModal
from llama_index.core.schema import ImageDocument
from llama_index.core.llms import ChatMessage

# 비교할 이미지 문서 준비
image_documents = [
    ImageDocument(image_path=input_image),
    ImageDocument(image_path=retrieved_images[0]),
]

openai_mm_llm = OpenAIMultiModal(
    model="gpt-4o-mini",
    api_key=api_key,
    max_new_tokens=1500
)

# 멀티모달 질의 수행
response = openai_mm_llm.complete(
    prompt="첫 번째 이미지의 화가를 알려주고, 같은 시대의 다른 화가 한 명과 그 대표 작품도함께 소개해주세요.",
    image_documents=image_documents
)

# 결과 출력
print(response.text)
# Out:
# 첫 번째 이미지는 폴 고갱(Paul Gauguin)의 작품입니다. 고갱은 19세기 후반 프랑스 인상파 화가로, 주로 타히티에서의 삶과 문화를 주제로 한 작품으로 유명합니다.
#
# 같은 시대의 다른 화가로는 빈센트 반 고흐(Vincent van Gogh)를 들 수 있습니다. 그의 대표 작품 중 하나는 **"별이 빛나는 밤"**(Starry Night)입니다. 반 고흐는 강렬한 색채와 독특한 붓질로 잘 알려져 있으며, 그의 작품은 감정과 표현을 중시합니다.
